# %%
# Ask the user to enter the names of files to compare
fname1 = input("Enter the first filename: ")
fname2 = input("Enter the second filename: ")
# Out:
# Enter the first filename: H:\saslog_v1.log
# Enter the second filename: H:\saslog_v2.log

# %%
# Open file for reading in text mode (default mode)
import string
f1 = open(fname1)
f2 = open(fname2)
elist=['SAS', 'cpu', 'NOTE:', 'real time', 'WARNING:']

# %%
# Read the first line from the files
F1_line = f1.readline()
F2_line = f2.readline()

try:
    firstdigits1=str([int(s) for s in F1_line.split() if s.isdigit()][0])
    f1_line=F1_line.replace(firstdigits1, "")
except IndexError:
    f1_line=F1_line

try:
    firstdigits2=str([int(s) for s in F2_line.split() if s.isdigit()][0])
    f2_line=F2_line.replace(firstdigits2, "")
except IndexError:
    f2_line=F2_line
    

# Initialize counter for line number
line_no = 1

# Print confirmation
print("-----------------------------------")
print("Comparing files: ", " v1: " + fname1, " v2: " + fname2, sep='\n')
print("-----------------------------------\n")

# Loop if either file1 or file2 has not reached EOF
print("Instruction:")
print("--If a line does not exist on the file, we mark the output with + sign.")
print("--Otherwise we output the line on the other file and mark it with a v1/v2 sign.\n")

while (f1_line != '' or f2_line != ''):
    
    if f1_line.strip() != f2_line.strip():
        
        # If a line does not exist on file2 then mark the output with + sign
        if f2_line == '' and f1_line != '':
            if all([s not in f1_line for s in elist]):
                print("v2+", "Line-%d:" % line_no, f1_line)
            else:
                pass

        # otherwise output the line on file1 and mark it with v2 sign
        elif f1_line != '':
            if all([s not in f1_line for s in elist]):
                print("v2", "Line-%d:" % line_no, f1_line)
            else:
                pass
            
        # If a line does not exist on file1 then mark the output with + sign
        if f1_line == '' and f2_line != '':
            if all([s not in f2_line for s in elist]):
                print("v1+", "Line-%d:" % line_no, f2_line)
            else:
                pass
            
        # otherwise output the line on file2 and mark it with v1 sign
        elif f2_line != '':
            if all([s not in f2_line for s in elist]):
                print("v1", "Line-%d:" %  line_no, f2_line)
            else:
                pass 

        # Print a blank line
        print()

    #Read the next line from the file
    F1_line = f1.readline()
    F2_line = f2.readline()
    
    try:
        firstdigits1=str([int(s) for s in F1_line.split() if s.isdigit()][0])
        f1_line=F1_line.replace(firstdigits1, "")
    except IndexError:
        f1_line=F1_line

    try:
        firstdigits2=str([int(s) for s in F2_line.split() if s.isdigit()][0])
        f2_line=F2_line.replace(firstdigits2, "")
    except IndexError:
        f2_line=F2_line
    
    #Increment line counter  
    line_no += 1

f1.close()
f2.close()

# References:
# http://www.opentechguides.com/how-to/article/python/58/python-file-comparison.html (Python SCRIPT)
# http://psych.colorado.edu/~carey/courses/psyc7291/SASExamples/anova.example.sas (SAS CODE)
# Out:
# -----------------------------------
# Comparing files:
#  v1: H:\saslog_v1.log
#  v2: H:\saslog_v2.log
# -----------------------------------
#
# Instruction:
# --If a line does not exist on the file, we mark the output with + sign.
# --Otherwise we output the line on the other file and mark it with a v1/v2 sign.
#
#
#
# v2 Line-30:    DATA rawscore;
#
# v1 Line-30:    DATA rawscore; /*PGao: added another data points */
#
#
#
# v2 Line-52:    proc print;
#
# v1 Line-52:    proc print; /*PGao: deleted variables*/
#
#
# v2 Line-54:       var  i group dgroup1 dgroup2 dgroup3 dgroup4 y;
#
# v1 Line-54:    var i y;
#
#
#
# v2 Line-92:    proc means noprint data=stats1;
#
# v1 Line-92:    TITLE4 BLAH; /*PGao: added another line*/
#
#
# v2 Line-93:       var mean_y var_y;
#
# v1 Line-93:    proc means noprint data=stats1;
#
#
# v2 Line-94:       output out=stats2 mean =  mu_hat   s2_error
#
# v1 Line-94:       var mean_y var_y;
#
#
# v2 Line-95:                         var  =  s2_xbar  stupid;
#
# v1 Line-95:       output out=stats2 mean =  mu_hat   s2_error
#
#
# v2 Line-96:    run;
#
# v1 Line-96:                         var  =  s2_xbar  stupid;
#
#
# v2 Line-97:
#
# v1 Line-97:    run;
#
#
# v1 Line-98:
#
#
#
#
#
#
# v2 Line-103:
#
#
# v2 Line-106:    proc print;
#
# v1 Line-106:    TITLE4 ; /*PGao: added another line*/
#
#
# v2 Line-107:        var mu_hat s2_xbar s2_error;
#
# v1 Line-107:
#
#
# v2 Line-108:    run;
#
# v1 Line-108:    proc print data=&syslast. (obs=1);  /*PGao: added another line and cleaned it up by shifting
#
#
# v2 Line-109:
#
# v1 Line-109:  ! blank space*/
#
#
# v1 Line-110:    var mu_hat s2_xbar              s2_error;
#
#
# v1 Line-111:    run;
#
#
# v1 Line-112:
#
#
#
# v2 Line-114:
#
#
# v2 Line-115:
#
#
# v2 Line-116:
#
#
# v2 Line-117:    TITLE2 An "ANOVA" table constructed from the variances;
#
# v1 Line-117:
#
#
# v1 Line-118:
#
#
# v2 Line-119:    data stats3;
#
# v1 Line-119:
#
#
# v2 Line-120:       set stats2;
#
# v1 Line-120:    TITLE2 An "ANOVA" table constructed from the variances;
#
#
# v2 Line-121:       source = 'Model';
#
#
# v2 Line-122:       s2_hat = 8*s2_xbar;
#
# v1 Line-122:    data stats3;
#
#
# v2 Line-123:       f      = s2_hat / s2_error;
#
# v1 Line-123:       set stats2;
#
#
# v2 Line-124:       pvalue = 1 - probf(f, 3, 28);
#
# v1 Line-124:       source = 'Model';
#
#
# v2 Line-125:       output;
#
# v1 Line-125:       s2_hat = 8*s2_xbar;
#
#
# v2 Line-126:       source = 'Error';
#
# v1 Line-126:       f      = s2_hat / s2_error;
#
#
# v2 Line-127:       s2_hat = s2_error;
#
# v1 Line-127:       pvalue = 1 - probf(f, 3, 28);
#
#
# v2 Line-128:       f      = .;
#
# v1 Line-128:       output;
#
#
# v2 Line-129:       pvalue = .;
#
# v1 Line-129:       source = 'Error';
#
#
# v2 Line-130:       output;
#
# v1 Line-130:       s2_hat = s2_error; /*PGao: blank space*/
#
#
# v2 Line-131:    run;
#
# v1 Line-131:
#
#
# v2 Line-132:
#
# v1 Line-132:       f      = .;
#
#
# v1 Line-133:      pvalue = .;
#
#
# v1 Line-134:      output;
#
#
# v1 Line-135:   run;
#
#
# v1 Line-136:
#
#
#
# v2 Line-138:
#
#
# v2 Line-139:
#
#
# v2 Line-140:
#
#
# v2 Line-141:
#
#
# v2 Line-142:   proc print;
#
# v1 Line-142:
#
#
# v2 Line-143:      var source s2_hat f pvalue;
#
# v1 Line-143:
#
#
# v2 Line-144:   run;
#
# v1 Line-144:
#
#
# v1 Line-146:   proc print; var source s2_hat f pvalue; run;
#
#
# v1 Line-147:
#
#
#
#
# v2 Line-150:
#
#
# v2 Line-151:
#
#
# v2 Line-153:   TITLE2 Results from PROC GLM;
#
# v1 Line-153:
#
#
# v2 Line-154:   TITLE3 Compare the ANOVA table to the one on the previous page;
#
# v1 Line-154: 105!                                              /*PGao: move everything in one line*/
#
#
# v2 Line-155:   proc glm data=rawscore;
#
# v1 Line-155:
#
#
# v2 Line-156:      class group;
#
# v1 Line-156:   TITLE2 Results from PROC GLM;
#
#
# v2 Line-157:      model y = group / solution;
#
# v1 Line-157:   TITLE3 Compare the ANOVA table to the one on the previous page;
#
#
# v2 Line-158:   run;
#
# v1 Line-158:   proc glm data=rawscore;
#
#
# v2 Line-159:
#
# v1 Line-159:      class group;
#
#
# v2 Line-160:
#
# v1 Line-160:      model y = group / solution;
#
#
# v2 Line-161:   TITLE2 Results from PROC REG;
#
# v1 Line-161:   run;
#
#
# v2 Line-162:   TITLE3 Compare the ANOVA table to the two above;
#
# v1 Line-162:
#
#
# v1 Line-164:   TITLE2 Results from PROC REG;
#
#
# v1 Line-165:   TITLE3 Compare the ANOVA table to the two above;
#
#
# v1 Line-166:
#
#
# v2 Line-167:
#
#
# v2 Line-168:
#
#
# v2 Line-169:   proc reg data=rawscore;
#
#
# v2 Line-170:      model y = dgroup1 dgroup2 dgroup3;
#
# v1 Line-170:
#
#
# v2 Line-171:   run;
#
# v1 Line-171:
#
#
# v2 Line-172:
#
# v1 Line-172:   proc reg data=rawscore;
#
#
# v2 Line-173:   quit;
#
# v1 Line-173:      model y = dgroup1 dgroup2 dgroup3;
#
#
# v2 Line-174:
#
# v1 Line-174:   run;
#
#
# v1 Line-175:
#
#
# v1 Line-176:   quit;
#
#
# v1 Line-177:
#
#
# v2 Line-178:
#
#
# v2 Line-179:
